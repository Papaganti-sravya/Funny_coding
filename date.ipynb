# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %% [markdown]
# Having two csv files

# %%
meetings = pd.read_csv("C:/Users/SRAVYA/OneDrive/Desktop/internship/meetlogs.csv", nrows = 10)
#Info_data

# %%
calender = pd.read_csv("C:/Users/SRAVYA/OneDrive/Desktop/internship/CalendarMeets.csv", nrows = 10)
#print(meetings)

# %% [markdown]
# Taking the meeting logs and modifying the data by filtering the columns we need like video received and send duration with city and date

# %%
data_set1 = meetings[['Video Receive Duration','Video Send Duration','City','Date']]
Meet = data_set1[data_set1['City'] == 'Nairobi']
date = calender[['1','2','3','4','5']]
#print(date)

# %% [markdown]
# Taking the second table and modifying the columns into the columns we need since the columns we have is 1,2,3,4,5

# %%
date.columns = ['Meet link','Participants','Unmodified Start Time','Unmodified End time','ID']
#date

# %% [markdown]
# Start time has the date and time zone, we will split this start time and end time start date, start time, end time, end date

# %%
date[['Start date','Start timeZone']] = date['Unmodified Start Time'].str.split(",",expand=True)
date[['End date','End timeZone']] = date['Unmodified End time'].str.split(",",expand=True)
date = date.drop(["Unmodified Start Time", "Unmodified End time"], axis=1)
date
# Out:
# C:\Users\SRAVYA\Anaconda3\lib\site-packages\pandas\core\frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                               Meet link  \
# 0                             Meet Link
# 1  https://meet.google.com/rtu-nbpv-eru
# 2  https://meet.google.com/qpc-swnw-dfs
# 3  https://meet.google.com/yby-pgmq-ify
# 4  https://meet.google.com/bmx-fyor-dbp
# 5  https://meet.google.com/ipv-aqzi-kmn
# 6  https://meet.google.com/vbs-enek-zhx
# 7  https://meet.google.com/vtw-ouho-mbm
# 8  https://meet.google.com/mvp-anxi-wqn
# 9  https://meet.google.com/xhy-qgxb-qeb
#
#                                         Participants  \
# 0                                       Participants
# ...

# %% [markdown]
# Since the date has datetime common in all the rows we will delete that text and modify the rows into the way we need

# %%
date['Start date'] = date['Start date'].astype(str).str.replace("{'dateTime':", '')

# %%
date['Start timeZone'] = date['Start timeZone'].astype(str).str.replace("'timeZone':", '')

# %%
date['End date'] = date['End date'].astype(str).str.replace("{'dateTime':", '')

# %%
date['End timeZone'] = date['End timeZone'].astype(str).str.replace("'timeZone':", '')

# %%
date
# Out:
#                               Meet link  \
# 0                             Meet Link
# 1  https://meet.google.com/rtu-nbpv-eru
# 2  https://meet.google.com/qpc-swnw-dfs
# 3  https://meet.google.com/yby-pgmq-ify
# 4  https://meet.google.com/bmx-fyor-dbp
# 5  https://meet.google.com/ipv-aqzi-kmn
# 6  https://meet.google.com/vbs-enek-zhx
# 7  https://meet.google.com/vtw-ouho-mbm
# 8  https://meet.google.com/mvp-anxi-wqn
# 9  https://meet.google.com/xhy-qgxb-qeb
#
#                                         Participants  \
# 0                                       Participants
# 1  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 2  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 3  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 4  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 5  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 6  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 7  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# ...

# %%
date[['Start date','Start time']] = date['Start date'].str.split("T0",expand=True)

# %%
date[['End date','End time']] = date['End date'].str.split("T0",expand=True)

# %%
date
# Out:
#                               Meet link  \
# 0                             Meet Link
# 1  https://meet.google.com/rtu-nbpv-eru
# 2  https://meet.google.com/qpc-swnw-dfs
# 3  https://meet.google.com/yby-pgmq-ify
# 4  https://meet.google.com/bmx-fyor-dbp
# 5  https://meet.google.com/ipv-aqzi-kmn
# 6  https://meet.google.com/vbs-enek-zhx
# 7  https://meet.google.com/vtw-ouho-mbm
# 8  https://meet.google.com/mvp-anxi-wqn
# 9  https://meet.google.com/xhy-qgxb-qeb
#
#                                         Participants  \
# 0                                       Participants
# 1  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 2  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 3  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 4  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 5  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 6  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 7  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# ...

# %%
data_set = Info_data[['Video Receive Duration','Video Send Duration','City','Date']]

# %%
data_set1 = data_set[data_set['City'] == 'Nairobi']

# %% [markdown]
# We will modify the date into different columsn as date month day and year.

# %%
data_set1['Date'] = pd.to_datetime(data_set1['Date'],format='%b %d, %Y, %H:%M:%S %p %Z-4')
data_set1['month']=data_set1['Date'].dt.month
data_set1['day']=data_set1['Date'].dt.day
data_set1['year']=data_set1['Date'].dt.year
# Out:
# C:\Users\SRAVYA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\SRAVYA\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\SRAVYA\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
data_set1
# Out:
#    Video Receive Duration  Video Send Duration     City  \
# 9                       0                  112  Nairobi
#
#                        Date  month  day  year
# 9 2021-09-17 11:03:47+00:00      9   17  2021

# %%
date
# Out:
#                               Meet link  \
# 0                             Meet Link
# 1  https://meet.google.com/rtu-nbpv-eru
# 2  https://meet.google.com/qpc-swnw-dfs
# 3  https://meet.google.com/yby-pgmq-ify
# 4  https://meet.google.com/bmx-fyor-dbp
# 5  https://meet.google.com/ipv-aqzi-kmn
# 6  https://meet.google.com/vbs-enek-zhx
# 7  https://meet.google.com/vtw-ouho-mbm
# 8  https://meet.google.com/mvp-anxi-wqn
# 9  https://meet.google.com/xhy-qgxb-qeb
#
#                                         Participants  \
# 0                                       Participants
# 1  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 2  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 3  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 4  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 5  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 6  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 7  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# ...

# %% [markdown]
# Concatinating above two modified csv files into one

# %%
frames = [date, data_set1]
result = pd.concat(frames)

# %%
result
# Out:
#                               Meet link  \
# 0                             Meet Link
# 1  https://meet.google.com/rtu-nbpv-eru
# 2  https://meet.google.com/qpc-swnw-dfs
# 3  https://meet.google.com/yby-pgmq-ify
# 4  https://meet.google.com/bmx-fyor-dbp
# 5  https://meet.google.com/ipv-aqzi-kmn
# 6  https://meet.google.com/vbs-enek-zhx
# 7  https://meet.google.com/vtw-ouho-mbm
# 8  https://meet.google.com/mvp-anxi-wqn
# 9  https://meet.google.com/xhy-qgxb-qeb
# 9                                   NaN
#
#                                         Participants  \
# 0                                       Participants
# 1  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 2  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 3  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 4  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 5  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# 6  [{'email': 'c_188apa1pg08nkg9pn621lmhbfc0f04gn...
# ...
